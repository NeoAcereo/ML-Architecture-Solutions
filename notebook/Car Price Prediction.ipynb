# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
np.set_printoptions(precision=3)

# %%
data = pd.read_csv("../data.csv")
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125               Tata Indigo CR4  2013         290000      25000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['torque'].iloc[2007:]
# Out:
# 2007          250Nm@ 1500-2500rpm
# 2008                59Nm@ 2500rpm
# 2009               135Nm@ 2500rpm
# 2010          195Nm@ 1440-2200rpm
# 2011          205Nm@ 1800-2800rpm
#                   ...
# 8122             113.7Nm@ 4000rpm
# 8123    24@ 1,900-2,750(kgm@ rpm)
# 8124               190Nm@ 2000rpm
# 8125          140Nm@ 1800-3000rpm
# 8126          140Nm@ 1800-3000rpm
# Name: torque, Length: 6120, dtype: object

# %%
data['engine']
# Out:
# 0       1248 CC
# 1       1498 CC
# 2       1497 CC
# 3       1396 CC
# 4       1298 CC
#          ...
# 8122    1197 CC
# 8123    1493 CC
# 8124    1248 CC
# 8125    1396 CC
# 8126    1396 CC
# Name: engine, Length: 8127, dtype: object

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125               Tata Indigo CR4  2013         290000      25000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
temp = data['max_power']

# %%
temp.drop(4933, axis=0, inplace=True)

# %%
temp.iloc[4933]
# Out:
# '90 bhp'

# %%
for index in data['max_power'].index:
    if data['max_power'].iloc[index] == ' ':
        print(index)

# %%
data['max_power'].drop(index=4932)
# Out:
# 0           74 bhp
# 1       103.52 bhp
# 2           78 bhp
# 3           90 bhp
# 4         88.2 bhp
#            ...
# 8122     82.85 bhp
# 8123       110 bhp
# 8124      73.9 bhp
# 8125        70 bhp
# 8126        70 bhp
# Name: max_power, Length: 8126, dtype: object

# %%
data['max_power'] = temp.map(lambda x: float(x.split(' ')[0]), na_action='ignore')

# %%
data['max_power']
# Out:
# 0        74.00
# 1       103.52
# 2        78.00
# 3        90.00
# 4        88.20
#          ...
# 8122     82.85
# 8123    110.00
# 8124     73.90
# 8125     70.00
# 8126     70.00
# Name: max_power, Length: 8127, dtype: float64

# %% [markdown]
# Since horsepower and torque are directly porpo

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125               Tata Indigo CR4  2013         290000      25000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['torque'][data['torque'].str.contains('kgm').fillna(False)].index
# Out:
# Int64Index([   2,    3,    4,    6,   17,  184,  226,  242,  250,  251,
#             ...
#             8070, 8075, 8076, 8078, 8080, 8081, 8103, 8104, 8112, 8123],
#            dtype='int64', length=478)

# %%
data['torque'][data['torque'].str.contains('kgm').fillna(0)]
# Out:
# 0         190Nm@ 2000rpm
# 0         190Nm@ 2000rpm
# 1    250Nm@ 1500-2500rpm
# 1    250Nm@ 1500-2500rpm
# 1    250Nm@ 1500-2500rpm
#             ...
# 0         190Nm@ 2000rpm
# 1    250Nm@ 1500-2500rpm
# 0         190Nm@ 2000rpm
# 0         190Nm@ 2000rpm
# 0         190Nm@ 2000rpm
# Name: torque, Length: 8127, dtype: object

# %%
index = data['torque'][data['torque'].str.contains('kgm').fillna(False)].index
index
# Out:
# Int64Index([   2,    3,    4,    6,   17,  184,  226,  242,  250,  251,
#             ...
#             8070, 8075, 8076, 8078, 8080, 8081, 8103, 8104, 8112, 8123],
#            dtype='int64', length=478)

# %%
df = data.copy()

# %%
df.columns.get_loc('torque')
# Out:
# 11

# %%
df['torque']
# Out:
# 0                  190Nm@ 2000rpm
# 1             250Nm@ 1500-2500rpm
# 2           12.7@ 2,700(kgm@ rpm)
# 3        22.4 kgm at 1750-2750rpm
# 4           11.5@ 4,500(kgm@ rpm)
#                   ...
# 8122             113.7Nm@ 4000rpm
# 8123    24@ 1,900-2,750(kgm@ rpm)
# 8124               190Nm@ 2000rpm
# 8125          140Nm@ 1800-3000rpm
# 8126          140Nm@ 1800-3000rpm
# Name: torque, Length: 8127, dtype: object

# %%
def get_torque(value):
    value = value.split(' ')[0]
    value = value.strip('@kgm')
    return float(value)

# %%
temp.iloc[4]
# Out:
# '88.2 bhp'

# %%
index = np.ravel(index)
index
# Out:
# array([   2,    3,    4,    6,   17,  184,  226,  242,  250,  251,  270,
#         280,  301,  324,  327,  330,  359,  394,  396,  397,  401,  435,
#         478,  514,  568,  587,  604,  638,  644,  671,  721,  745,  752,
#         769,  805,  824,  831,  840,  845,  852,  856,  876,  888,  889,
#         897,  898,  903,  905,  919,  940,  950,  960,  964,  993,  996,
#        1004, 1023, 1024, 1038, 1044, 1156, 1177, 1187, 1211, 1234, 1256,
#        1257, 1264, 1265, 1282, 1371, 1404, 1412, 1421, 1426, 1429, 1456,
#        1479, 1513, 1523, 1536, 1614, 1629, 1658, 1659, 1663, 1667, 1686,
#        1694, 1732, 1754, 1760, 1762, 1770, 1780, 1807, 1816, 1824, 1829,
#        1855, 1883, 1942, 1971, 1990, 1998, 2005, 2023, 2076, 2080, 2085,
#        2107, 2116, 2165, 2222, 2236, 2238, 2242, 2256, 2288, 2313, 2319,
#        2320, 2332, 2344, 2383, 2401, 2420, 2422, 2424, 2434, 2440, 2477,
#        2478, 2535, 2585, 2591, 2611, 2652, 2706, 2788, 2803, 2804, 2820,
# ...

# %%
temp = data.iloc[index]['torque'].map(get_torque, na_action='ignore')
temp
# Out:
# 2       12.7
# 3       22.4
# 4       11.5
# 6        7.8
# 17      22.4
#         ...
# 8081    16.3
# 8103    13.5
# 8104    11.3
# 8112    20.4
# 8123    24.0
# Name: torque, Length: 478, dtype: float64

# %%
def convert_to_Nm(value):
    value = 9.80665 * value
    return value

# %%
temp = temp.map(convert_to_Nm, na_action='ignore')

# %%
for i, value in zip(index, temp):
    df.iloc[i,11] = value

# %%
def get_value(value):
    if(type(value) is float or type(value) is int):
        return value
    else:
        value = value.split(' ')
        value = value[0].split('@')
        value = value[0].strip('nNmM')
        return float(value)

# %%
data['torque'] = df['torque'].map(get_value, na_action='ignore')

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125               Tata Indigo CR4  2013         290000      25000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['mileage'] = data['mileage'].map(lambda x: float(x.split(' ')[0]), na_action='ignore')

# %%
data['engine'] = data['engine'].map(lambda x: float(x.split(' ')[0]), na_action='ignore')
data.rename(columns={'engine': 'engine (CC)',
                     'mileage': 'mileage (kmpl)'}, inplace=True)

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125               Tata Indigo CR4  2013         290000      25000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# ### Getting Rid of NAN Values

# %%
data.isna().sum()
# Out:
# name                0
# year                0
# selling_price       0
# km_driven           0
# fuel                0
# seller_type         0
# transmission        0
# owner               0
# mileage (kmpl)    221
# engine (CC)       221
# max_power         223
# torque            222
# seats             221
# dtype: int64

# %%
num_features = data.select_dtypes(include=['int', 'float']).columns
num_features = num_features.drop('year')
num_features = num_features.drop('selling_price')
num_features = list(num_features)
num_features
# Out:
# ['km_driven', 'mileage (kmpl)', 'engine (CC)', 'max_power', 'torque', 'seats']

# %%
from sklearn.impute import KNNImputer
num_imputer = KNNImputer(missing_values=np.nan, n_neighbors=3, weights='uniform')
#num_imputer.set_output(transform='pandas')
data[num_features] = num_imputer.fit_transform(data[num_features])

# %%
data.isna().sum()
# Out:
# name              0
# year              0
# selling_price     0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage (kmpl)    0
# engine (CC)       0
# max_power         0
# torque            0
# seats             0
# dtype: int64

# %%
cleaned_data = data.copy()

# %%
cleaned_data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000   145500.0  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000   120000.0  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000   140000.0  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000   127000.0  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000   120000.0  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000   110000.0  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000   119000.0  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000   120000.0  Diesel
# 8125               Tata Indigo CR4  2013         290000    25000.0  Diesel
# 8126               Tata Indigo CR4  2013         290000    25000.0  Diesel
#
# ...

# %%
import seaborn as sns

for feature_ in num_features:
    sns.displot(data=cleaned_data[feature_], kind='kde')

# %% [markdown]
# ## Data Visualization

# %%
cat_features = cleaned_data.select_dtypes(include='object').columns

# %%
cat_features = list(cat_features)
cat_features
# Out:
# ['name', 'fuel', 'seller_type', 'transmission', 'owner']

# %% [markdown]
# Year is also added to the list of categorical variables since it does not represent a quantity.

# %%
cat_features.append('year')

# %%
cat_features
# Out:
# ['name', 'fuel', 'seller_type', 'transmission', 'owner', 'year']

# %%
cleaned_data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000   145500.0  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000   120000.0  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000   140000.0  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000   127000.0  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000   120000.0  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000   110000.0  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000   119000.0  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000   120000.0  Diesel
# 8125               Tata Indigo CR4  2013         290000    25000.0  Diesel
# 8126               Tata Indigo CR4  2013         290000    25000.0  Diesel
#
# ...

# %%
import seaborn as sns

for feature in cat_features:
    plot_data = pd.concat([data['selling_price'], data[feature]], axis=1)
    plt.figure(figsize=(12,8))
    plt.xticks(rotation=90)
    plt.ylim(1.5, 10**7)
    fig = sns.boxplot(x=feature, y='selling_price', data=plot_data)

# %% [markdown]
# Since the name variable has too much noise, it will be dropped

# %%
cleaned_data.drop('name', axis=1, inplace=True)

# %% [markdown]
# The correlation between the numerical features and target.

# %%
correlation = cleaned_data[num_features].corr()
params = dict(data=correlation,
              annot=True,
              cmap='YlGnBu')
sns.heatmap(**params)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap above, it can be observed that the Max Power, Torque, and Engine variables have a high positive correlation with each other. Since the Max Power variable is the most predictive in relation to the target, it will be maintained dropping the rest.

# %%
cleaned_data.drop(['engine (CC)', 'torque'], axis=1, inplace=True)
cleaned_data
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000   145500.0  Diesel  Individual       Manual
# 1     2014         370000   120000.0  Diesel  Individual       Manual
# 2     2006         158000   140000.0  Petrol  Individual       Manual
# 3     2010         225000   127000.0  Diesel  Individual       Manual
# 4     2007         130000   120000.0  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8122  2013         320000   110000.0  Petrol  Individual       Manual
# 8123  2007         135000   119000.0  Diesel  Individual       Manual
# 8124  2009         382000   120000.0  Diesel  Individual       Manual
# 8125  2013         290000    25000.0  Diesel  Individual       Manual
# 8126  2013         290000    25000.0  Diesel  Individual       Manual
#
#                      owner  mileage (kmpl)  max_power  seats
# 0              First Owner           23.40      74.00    5.0
# ...

# %%
num_features.remove('engine (CC)')
num_features.remove('torque')

# %%
correlation = data[num_features].corr()
params['data'] = correlation
sns.heatmap(**params)
plt.tight_layout()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Since the year variable is of ordinal type it will be converted accordingly.

# %%
preprocessed_data = cleaned_data.copy()

# %%
index = np.argsort(preprocessed_data['year'].unique())

# %%
index
# Out:
# array([21, 28, 24, 25, 23, 27, 26, 19, 20,  5, 12, 15, 22,  8,  1,  3, 17,
#         9,  2,  6, 11,  7,  0, 13, 10,  4, 14, 16, 18], dtype=int64)

# %%
preprocessed_data['year'].unique()[index]
# Out:
# array([1983, 1991, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
preprocessed_data['year'].nunique()
# Out:
# 29

# %% [markdown]
# The year variable will be aggregated into groups because of its high cardinality.

# %%
year = preprocessed_data['year']

year_ranges = pd.IntervalIndex.from_tuples([(1983, 1996), (1997, 2001), (2002, 2006), (2007, 2011),
                                           (2012, 2016), (2017, 2020)], closed='both')

labels = [1, 2, 3, 4, 5, 6]
year_groups = pd.cut(x=year, bins=year_ranges)
year_groups = year_groups.cat.rename_categories(labels)
preprocessed_data['year'] = year_groups

# %%
preprocessed_data['year']
# Out:
# 0       5
# 1       5
# 2       3
# 3       4
# 4       4
#        ..
# 8122    5
# 8123    4
# 8124    4
# 8125    5
# 8126    5
# Name: year, Length: 8127, dtype: category
# Categories (6, int64): [1 < 2 < 3 < 4 < 5 < 6]

# %%
cat_features.remove('name')
cat_features.remove('year')

# %%
cat_features
# Out:
# ['fuel', 'seller_type', 'transmission', 'owner']

# %%
preprocessed_data[cat_features]
# Out:
#         fuel seller_type transmission                 owner
# 0     Diesel  Individual       Manual           First Owner
# 1     Diesel  Individual       Manual          Second Owner
# 2     Petrol  Individual       Manual           Third Owner
# 3     Diesel  Individual       Manual           First Owner
# 4     Petrol  Individual       Manual           First Owner
# ...      ...         ...          ...                   ...
# 8122  Petrol  Individual       Manual           First Owner
# 8123  Diesel  Individual       Manual  Fourth & Above Owner
# 8124  Diesel  Individual       Manual           First Owner
# 8125  Diesel  Individual       Manual           First Owner
# 8126  Diesel  Individual       Manual           First Owner
#
# [8127 rows x 4 columns]

# %%
params = dict(data=preprocessed_data,
              columns=cat_features,
              dtype=int)
                        

preprocessed_data = pd.get_dummies(**params)

# %%
preprocessed_data
# Out:
#      year  selling_price  km_driven  mileage (kmpl)  max_power  seats  \
# 0       5         450000   145500.0           23.40      74.00    5.0
# 1       5         370000   120000.0           21.14     103.52    5.0
# 2       3         158000   140000.0           17.70      78.00    5.0
# 3       4         225000   127000.0           23.00      90.00    5.0
# 4       4         130000   120000.0           16.10      88.20    5.0
# ...   ...            ...        ...             ...        ...    ...
# 8122    5         320000   110000.0           18.50      82.85    5.0
# 8123    4         135000   119000.0           16.80     110.00    5.0
# 8124    4         382000   120000.0           19.30      73.90    5.0
# 8125    5         290000    25000.0           23.57      70.00    5.0
# 8126    5         290000    25000.0           23.57      70.00    5.0
#
#       fuel_CNG  fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Dealer  \
# ...

# %% [markdown]
# ## Scaling Numerical Features

# %%
preprocessed_data[num_features].describe()
# Out:
#           km_driven  mileage (kmpl)    max_power        seats
# count  8.127000e+03     8127.000000  8127.000000  8127.000000
# mean   6.981826e+04       19.418658    91.504864     5.414831
# std    5.655392e+04        3.995690    35.456992     0.949984
# min    1.000000e+00        0.000000    32.800000     2.000000
# 25%    3.500000e+04       16.800000    68.050000     5.000000
# 50%    6.000000e+04       19.300000    82.400000     5.000000
# 75%    9.800000e+04       22.300000   102.000000     5.000000
# max    2.360457e+06       42.000000   400.000000    14.000000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#scaler.set_output(transform='pandas')
preprocessed_data[num_features] = scaler.fit_transform(preprocessed_data[num_features])

# %%
preprocessed_data
# Out:
#      year  selling_price  km_driven  mileage (kmpl)  max_power     seats  \
# 0       5         450000   1.338305        0.996470  -0.493723 -0.436699
# 1       5         370000   0.887380        0.430826   0.338886 -0.436699
# 2       3         158000   1.241047       -0.430154  -0.380904 -0.436699
# 3       4         225000   1.011163        0.896356  -0.042445 -0.436699
# 4       4         130000   0.887380       -0.830610  -0.093213 -0.436699
# ...   ...            ...        ...             ...        ...       ...
# 8122    5         320000   0.710547       -0.229926  -0.244110 -0.436699
# 8123    4         135000   0.869697       -0.655411   0.521654 -0.436699
# 8124    4         382000   0.887380       -0.029698  -0.496544 -0.436699
# 8125    5         290000  -0.792536        1.039019  -0.606543 -0.436699
# 8126    5         290000  -0.792536        1.039019  -0.606543 -0.436699
#
#       fuel_CNG  fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Dealer  \
# ...

# %%
for num_feature_ in num_features:
    sns.displot(preprocessed_data[num_feature_], kde=True)

# %% [markdown]
# ## Model Selection and Evaluation

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Splitting data into train, train_dev, dev, and test sets.

# %%
from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split

selected_index = []

train_set = preprocessed_data.sample(frac=0.7, random_state=42)

selected_index.append(train_set.index)

test_set = preprocessed_data[~preprocessed_data.index.isin(train_set.index)]

#selected_index.append(train_set.index)

# %%
X_train_set = train_set.drop('selling_price', axis=1)
y_train_set = train_set['selling_price']

X_train, X_train_dev, y_train, y_train_dev = train_test_split(X_train_set, y_train_set, random_state=42, test_size=0.1)

# %%
X_test_set = test_set.drop('selling_price', axis=1)
y_test_set = test_set['selling_price']

X_val, X_test, y_val, y_test = train_test_split(X_test_set, y_test_set, random_state=42, test_size=0.1)

# %%
y_val
# Out:
# 1441    690000
# 2786    325000
# 6070    890000
# 6076    500000
# 6769    250000
#          ...
# 5390    350000
# 3582    550000
# 3701    350000
# 4225    625000
# 2866    400000
# Name: selling_price, Length: 2194, dtype: int64

# %%
test = preprocessed_data[~preprocessed_data.index.isin(train_set.index)].sample(frac=0.5, random_state=42)
test
# Out:
#      year  selling_price  km_driven  mileage (kmpl)  max_power     seats  \
# 1500    4         135000   0.533714        0.097947  -0.661542 -0.436699
# 6941    5         280000  -0.085203        0.235604  -0.355519 -0.436699
# 4485    6         490000  -1.110836        0.553466  -0.691158 -0.436699
# 885     5         371000  -0.527286       -0.305012  -0.256802 -0.436699
# 7203    4         210000   0.356880       -0.129812  -0.688337 -0.436699
# ...   ...            ...        ...             ...        ...       ...
# 5536    3         200000   1.921855       -0.430154  -0.380904 -0.436699
# 1066    6        1925000  -0.474236       -2.016962   2.256256  2.721444
# 1495    5         400000   0.356880       -0.865650  -0.829362  1.668730
# 6407    5         355000   0.356880       -0.480211  -0.160905 -0.436699
# 4226    6         600000  -0.000694        0.646071  -0.273725 -0.436699
#
#       fuel_CNG  fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Dealer  \
# ...

# %%
train_set.index.ravel()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_83584\1951616146.py:1: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   train_set.index.ravel()
# array([1971, 4663, 5447, ...,  986, 6453, 7374], dtype=int64)

# %%
test_set.index.ravel()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_83584\2822549603.py:1: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   test_set.index.ravel()
# array([   1,    2,    3, ..., 8115, 8123, 8126], dtype=int64)

# %% [markdown]
# ## Model Selection and Evaluation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

lr = LinearRegression()
svm = SVR(degree=5)
rf = RandomForestRegressor()
et = ExtraTreesRegressor()

[model.fit(X_train, y_train) for model in [lr, svm, rf, et]]
# Out:
# [LinearRegression(),
#  SVR(degree=5),
#  RandomForestRegressor(),
#  ExtraTreesRegressor()]

# %% [markdown]
# #### Checking for overfitting and data mismatch

# %% [markdown]
# To check if the model is either overfitting or there is a data mismatch, a train-dev set which is held out from the original training data is used. If the model performs well on the train-dev set, it means it does not overfit.
# After checking the performance of the model on the validation or dev set, you then compare it with its performance on the train-dev set. If the difference in performance is stark, then there is a data mismatch.

# %%
# Helper function for checking overfitting
# and data mismatch
def calculate_dev_set_scores(model):
    print(f'Train score for {model}: {model.score(X_train, y_train)}')
    print(f'Train-dev score {model}: {model.score(X_train_dev, y_train_dev)}')
    print(f'Validation score {model}: {model.score(X_val, y_val)}')
    print('\n')

# %%
[calculate_dev_set_scores(model) for model in [lr, svm, rf]]
# Out:
# Train score for LinearRegression(): 0.6975259499156226
# Train-dev score LinearRegression(): 0.7128463267466072
# Validation score LinearRegression(): 0.607958873102959
#
#
# Train score for SVR(degree=5): -0.05437038877851896
# Train-dev score SVR(degree=5): -0.051321998474069375
# Validation score SVR(degree=5): -0.0548498704709679
#
#
# Train score for RandomForestRegressor(): 0.9932136279071873
# Train-dev score RandomForestRegressor(): 0.9196356847623719
# Validation score RandomForestRegressor(): 0.956299339822975
# [None, None, None]

# %% [markdown]
# It can then be concluded that no model is overfitting the data, neither is there a data mismatch.

# %%
class AutoVivification(dict): # dynamic dictionary
    def __getitem__(self, item):
        try:
            return dict.__getitem__(self, item)
        except KeyError:
            value = self[item] = type(self)()
            return value

# %%
def evaluate_models(models, scorers, X_test, y_test):
    """Evaluate trained models on given scores and prints out the metric score of each trained model.
    models:
        Must be a list of tuples with each tuple having the model name and the trained model instance.
    scorers:
        Must be a list of tuples with each tuple having the score name and the scorer instance.
    X_test:
        The feature test set. Must be of size (n_features, n_samples)
    y_test:
        The target test set. Must be of size (n_samples,)
     """
    model_scores = AutoVivification()
    for(model_name, model) in models:
        print(f'Test Scores of {model_name} ')
        for (score_name, scorer) in scorers:        
            test_score = scorer(y_true=y_test, y_pred=model.predict(X_test))
            model_scores[model_name][score_name] = test_score
            print(f'{score_name} : {test_score:.4f}')
        print('\n')

# %%
from sklearn.metrics import r2_score

def find_mape(y_true, y_pred):

    if not all([isinstance(y_pred, np.ndarray),
                isinstance(y_true, np.ndarray)]):
        y_pred, y_true = np.array(y_pred),\
        np.array(y_true)
        
    percentage_error = np.absolute((y_pred - y_true)/ y_true) * 100
    mape = round(np.mean(percentage_error), 2)
    return mape

# %%
mape = find_mape
scorers = [('r2', r2_score), ('mape', mape)]
models = [('Linear Regression', lr), ('SVM', svm), ('Random Forest', rf)]

evaluate_models(models=models, scorers=scorers, X_test=X_test, y_test=y_test)
# Out:
# Test Scores of Linear Regression
# r2 : 0.6306
# mape : 82.1100
#
#
# Test Scores of SVM
# r2 : -0.0635
# mape : 83.5300
#
#
# Test Scores of Random Forest
# r2 : 0.9257
# mape : 18.9100

# %%
from sklearn.ensemble import ExtraTreesRegressor

ex_model = ExtraTreesRegressor()
ex_model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor()

# %%
ex_model.score(X_test, y_test)
# Out:
# 0.9213812573089728

# %%
best_rf = search_grid.best_estimator_
best_rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [84], line 1
# ----> 1 best_rf = search_grid.best_estimator_
#       2 best_rf.fit(X_train, y_train)
#
# NameError: name 'search_grid' is not defined

# %%
best_rf.score(X=X_test, y=y_test)
