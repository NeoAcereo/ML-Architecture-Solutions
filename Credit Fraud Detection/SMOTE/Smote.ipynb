# %%
from importlib import import_module

lib_names = [('numpy', 'np'), ('pandas', 'pd'), ('matplotlib.pyplot','plt'), ('seaborn','sns')]
for (lib_name, short_hand) in lib_names:
    try:
        lib = import_module(lib_name)
    except:
        print(sys.exc_info())
    else:
        globals()[short_hand] = lib

# %%
dataset = pd.read_csv('creditcard.csv')
dataset.head(20)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# 13  11.0  1.069374  0.287722  0.828613  2.712520 -0.178398  0.337544
# 14  12.0 -2.791855 -0.327771  1.641750  1.767473 -0.136588  0.807596
# 15  12.0 -0.752417  0.345485  2.057323 -1.468643 -1.158394 -0.077850
# 16  12.0  1.103215 -0.040296  1.267332  1.289091 -0.735997  0.288069
# 17  13.0 -0.436905  0.918966  0.924591 -0.727219  0.915679 -0.127867
# 18  14.0 -5.401258 -5.450148  1.186305  1.736239  3.049106 -1.763406
# 19  15.0  1.492936 -1.029346  0.454795 -1.438026 -1.555434 -0.720961
#
#           V7        V8        V9  ...       V21       V22       V23       V24  \
# 0   0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1  -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2   0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3   0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4   0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
# 5   0.476201  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427
# 6  -0.005159  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055
# 7   1.120631 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709
# 8   0.370145  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592
# 9   0.651583  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050
# 10 -1.423236  0.048456 -1.720408  ... -0.009302  0.313894  0.027740  0.500512
# 11  0.470455  0.538247 -0.558895  ...  0.049924  0.238422  0.009130  0.996710
# 12 -0.689405 -0.227487 -2.094011  ... -0.231809 -0.483285  0.084668  0.392831
# 13 -0.096717  0.115982 -0.221083  ... -0.036876  0.074412 -0.071407  0.104744
# 14 -0.422911 -1.907107  0.755713  ...  1.151663  0.222182  1.020586  0.028317
# 15 -0.608581  0.003603 -0.436167  ...  0.499625  1.353650 -0.256573 -0.065084
# 16 -0.586057  0.189380  0.782333  ... -0.024612  0.196002  0.013802  0.103758
# 17  0.707642  0.087962 -0.665271  ... -0.194796 -0.672638 -0.156858 -0.888386
# 18 -1.559738  0.160842  1.233090  ... -0.503600  0.984460  2.458589  0.042119
# 19 -1.080664 -0.053127 -1.978682  ... -0.177650 -0.175074  0.040002  0.295814
#
#          V25       V26       V27       V28  Amount  Class
# 0   0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1   0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2  -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3   0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4  -0.206010  0.502292  0.219422  0.215153   69.99      0
# 5  -0.232794  0.105915  0.253844  0.081080    3.67      0
# 6   0.750137 -0.257237  0.034507  0.005168    4.99      0
# 7  -0.415267 -0.051634 -1.206921 -1.085339   40.80      0
# 8   0.373205 -0.384157  0.011747  0.142404   93.20      0
# 9  -0.069733  0.094199  0.246219  0.083076    3.68      0
# 10  0.251367 -0.129478  0.042850  0.016253    7.80      0
# 11 -0.767315 -0.492208  0.042472 -0.054337    9.99      0
# 12  0.161135 -0.354990  0.026416  0.042422  121.50      0
# 13  0.548265  0.104094  0.021491  0.021293   27.50      0
# 14 -0.232746 -0.235557 -0.164778 -0.030154   58.80      0
# 15 -0.039124 -0.087086 -0.180998  0.129394   15.99      0
# 16  0.364298 -0.382261  0.092809  0.037051   12.99      0
# 17 -0.342413 -0.049027  0.079692  0.131024    0.89      0
# 18 -0.481631 -0.621272  0.392053  0.949594   46.80      0
# 19  0.332931 -0.220385  0.022298  0.007602    5.00      0
#
# [20 rows x 31 columns]

# %%
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
sns.countplot(dataset['Class'])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
# upsampling the fraud cases

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority', random_state=42)


oversampled_X, oversampled_Y = smote.fit_resample(dataset.drop('Class', axis=1), dataset['Class'])
oversampled_dataset = pd.concat([pd.DataFrame(oversampled_Y), pd.DataFrame(oversampled_X)], axis=1)

# %%
sns.countplot(oversampled_dataset['Class'])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
oversampled_dataset.shape
# Out:
# (568630, 31)

# %%
oversampled_dataset['Class'].value_counts()
# Out:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %%
oversampled_dataset = oversampled_dataset[['V1', 'V2', 'Time', 'Amount', 'Class']]

# %%
features = oversampled_dataset.drop(['Class'], axis=1)
target = oversampled_dataset['Class']

# %%
features
# Out:
#               V1        V2           Time      Amount
# 0      -1.359807 -0.072781       0.000000  149.620000
# 1       1.191857  0.266151       0.000000    2.690000
# 2      -1.358354 -1.340163       1.000000  378.660000
# 3      -0.966272 -0.185226       1.000000  123.500000
# 4      -1.158233  0.877737       2.000000   69.990000
# ...          ...       ...            ...         ...
# 568625 -6.379157  1.672637  144838.659385    7.334751
# 568626 -2.479028  0.958932   65965.011763   74.507571
# 568627 -1.799894  2.368957   34592.129093  102.486823
# 568628  0.255234  2.432041  129683.002907   58.346854
# 568629 -4.453646  3.210469   91471.277869  143.872749
#
# [568630 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=0) 
X_test
# Out:
#                V1         V2           Time      Amount
# 484657 -21.784422  12.888938   26893.623174   99.990000
# 409771 -22.197110  15.491638  100293.978405    1.068635
# 419226  -2.499415   3.110497   85707.360798    1.000000
# 89221   -3.285261   1.830862   62481.000000   89.990000
# 365095   0.117263   3.823907  160848.333093    0.833081
# ...           ...        ...            ...         ...
# 547468  -1.185718   0.508827  123088.353388   11.799319
# 357254  -6.299115   7.109899   93853.442961   45.907395
# 348749   0.721102   1.918636   40163.127645  161.090967
# 147219   2.286920  -1.602831   88253.000000   15.000000
# 396321  -4.259485   5.177387   35937.106370   79.118059
#
# [170589 rows x 4 columns]

# %%
sns.countplot(y_train)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
y_train.value_counts()
# Out:
# 0    199143
# 1    198898
# Name: Class, dtype: int64

# %%
y_test.value_counts()
# Out:
# 1    85417
# 0    85172
# Name: Class, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression

# %%
numerical_columns = oversampled_dataset.drop('Class', axis=1).columns

numerical_pipe = Pipeline([
    ('imputing', SimpleImputer(strategy='mean')),
    
    ('scaling', StandardScaler())
])

preprocessing = ColumnTransformer([
    ('numerical transformation', numerical_pipe, numerical_columns)
])

rf_classifier = RandomForestClassifier(n_estimators=300, random_state=42, n_jobs=-1)

ada_classifier = AdaBoostClassifier(estimator=LogisticRegression(), n_estimators=300, random_state=42)

models = [rf_classifier, ada_classifier]

model_labels = ['RandomForest', 'AdaBoost']

model_pipes = dict()

for model_label, model in zip(model_labels, models):
    model_pipes[model_label] =  Pipeline([
    ('preprocessing', preprocessing),
    ('classification', model)
])

# %%
class AutoVivification(dict):
    """Implementation of perl's autovivification feature."""
    def __getitem__(self, item):
        try:
            return dict.__getitem__(self, item)
        except KeyError:
            value = self[item] = type(self)()
            return value

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix



def calculate_classification_metrics(X_train, y_train, X_test, y_true, metrics, models):
    
    """
    Calculates performance metrics of chosen classifiers. 
    
    Parameters:
    
        X_train:
        The features values used for training the algorithm.
        
        y_train:
        The target feature values used for training the algorithm.
        
        X_test:
        The values of features used for the test predictions.
    
        y_true:
        The expected values of the target feature.
        
        
        metrics:
        a dictionary having the names of the metrics as keys and the metric objects as values.
        
        models:
        a dictionary having the names of the models as keys and the model objects or instances as values.
        
    returns:
        A nested dictionary of the models and their scores. The model names serve as the keys for the
        first level with the metric names serving as the keys for the second level.
    """
    model_scores = AutoVivification()
    
    for model in models:
        models[model].fit(X_train, y_train)
        for metric in metrics:
            predictions = models[model].predict(X_test)
            score = metrics[metric](y_true, predictions)
            model_scores[model][metric] = score
            
    return model_scores

# %%
metrics = {'accuracy':accuracy_score, 'precision':precision_score, 'recall':recall_score}

model_scores = calculate_classification_metrics(X_train= X_train,
                                                y_train= y_train,
                                                X_test=X_test,
                                                y_true=y_test, 
                                                metrics=metrics,
                                                models=model_pipes)

# %%
pd.DataFrame(model_scores)
# Out:
#            RandomForest  AdaBoost
# accuracy       0.991746  0.833155
# precision      0.986225  0.911947
# recall         0.997448  0.738050
