# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('house prediction_train.csv')

# %%
dataset.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
dataset = dataset.drop(['Id'], axis=1)

# %%
dataset.head(20)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           60       RL         65.0     8450   Pave   NaN      Reg
# 1           20       RL         80.0     9600   Pave   NaN      Reg
# 2           60       RL         68.0    11250   Pave   NaN      IR1
# 3           70       RL         60.0     9550   Pave   NaN      IR1
# 4           60       RL         84.0    14260   Pave   NaN      IR1
# 5           50       RL         85.0    14115   Pave   NaN      IR1
# 6           20       RL         75.0    10084   Pave   NaN      Reg
# 7           60       RL          NaN    10382   Pave   NaN      IR1
# 8           50       RM         51.0     6120   Pave   NaN      Reg
# 9          190       RL         50.0     7420   Pave   NaN      Reg
# 10          20       RL         70.0    11200   Pave   NaN      Reg
# 11          60       RL         85.0    11924   Pave   NaN      IR1
# 12          20       RL          NaN    12968   Pave   NaN      IR2
# ...

# %%
#dataset cleaning and preparation
#dataset insights and understanding

# %%
dataset_2 = dataset

# %%
temp = dataset.isna().any().astype(str)

# %%
na_columns = []
for column in dataset.columns:
    if(temp[column] == 'True'):
        na_columns.append(column)

# %%
na_columns
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
# Out:
# 1460

# %%
# taking out all features with 80% or
# more of their values missing

for column in na_columns:
    na_count=0
    for values in dataset[column].astype(str): 
    
        if (values == 'nan'):
            na_count +=1
            
    if(na_count >= 0.8 * len(dataset)):
        dataset_2 = dataset_2.drop([column], axis=1)

# %%
dataset_2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave  None      Reg
# 1             20       RL         80.0     9600   Pave  None      Reg
# 2             60       RL         68.0    11250   Pave  None      IR1
# 3             70       RL         60.0     9550   Pave  None      IR1
# 4             60       RL         84.0    14260   Pave  None      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave  None      Reg
# 1456          20       RL         85.0    13175   Pave  None      Reg
# 1457          70       RL         66.0     9042   Pave  None      Reg
# 1458          20       RL         68.0     9717   Pave  None      Reg
# 1459          20       RL         75.0     9937   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# ...

# %%
for column in na_columns:
    na_count=0
    for values in dataset[column].astype(str): 
    
        if (values == 'nan'):
            na_count +=1
    print(f'{column}: na_count:{na_count}')
# Out:
# LotFrontage: na_count:259
# Alley: na_count:0
# MasVnrType: na_count:0
# MasVnrArea: na_count:0
# BsmtQual: na_count:0
# BsmtCond: na_count:0
# BsmtExposure: na_count:0
# BsmtFinType1: na_count:0
# BsmtFinType2: na_count:0
# Electrical: na_count:0
# FireplaceQu: na_count:0
# GarageType: na_count:0
# GarageYrBlt: na_count:0
# GarageFinish: na_count:0
# GarageQual: na_count:0
# GarageCond: na_count:0
# PoolQC: na_count:0
# Fence: na_count:0
# MiscFeature: na_count:0

# %%
dataset_2['LotFrontage'] = dataset_2['LotFrontage'].fillna(dataset_2['LotFrontage'].mean(), inplace=True)

# %%
temp_2 = dataset_2.isna().any().astype(str)

na_columns_2 = []
for column in dataset_2.columns:
    if(temp[column] == 'True'):
        na_columns_2.append(column)

# %%
na_columns.remove('LotFrontage')

# %%
na_columns
# Out:
# ['Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for column in na_columns:
    dataset_2[column] = dataset_2[column].fillna(dataset_2[column].mode(), inplace=True)

# %%
dataset_2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave  None      Reg
# 1             20       RL         80.0     9600   Pave  None      Reg
# 2             60       RL         68.0    11250   Pave  None      IR1
# 3             70       RL         60.0     9550   Pave  None      IR1
# 4             60       RL         84.0    14260   Pave  None      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave  None      Reg
# 1456          20       RL         85.0    13175   Pave  None      Reg
# 1457          70       RL         66.0     9042   Pave  None      Reg
# 1458          20       RL         68.0     9717   Pave  None      Reg
# 1459          20       RL         75.0     9937   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# ...

# %%
len(dataset.columns)
# Out:
# 80
